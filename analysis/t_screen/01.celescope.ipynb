# %%
from celescope.tools import featureCounts, barcode, multi
import pandas as pd
import scanpy as sc

import matplotlib.pyplot as plt
import numpy as np

from bin import utils
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from celescope.tools import featureCounts, barcode, multi
#       2 import pandas as pd
#       3 import scanpy as sc
#
# File ~/miniconda3/envs/celescope/lib/python3.9/site-packages/celescope/tools/multi.py:11
#       9 from celescope.tools.__init__ import FILTERED_MATRIX_DIR_SUFFIX, STAR_BAM_SUFFIX
#      10 from celescope.tools import utils
# ---> 11 from celescope.celescope import ArgFormatter
#      12 from celescope.__init__ import HELP_DICT
#      13 from celescope.tools.make_ref import MakeRef
#
# File ~/miniconda3/envs/celescope/lib/python3.9/site-packages/celescope/celescope.py:12
#       1 import argparse
#       3 # On some system, import scanpy will report "ImportError: dlopen: cannot load any more object with static TLS" when scanpy import sklearn
#       4 # as described in
# ...

# %%
adata = sc.read_h5ad('./RNA/sc.combined.')
