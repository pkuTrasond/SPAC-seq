# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
samples = [
    "/home/wpy/stereoseq/in_vivo_T_68/B922/out-B922-8-1/03.count/D03658A1.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B922/out-B922-8-2/B922-8-2/03.count/D03658A1.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B922/out-B922-8-3/B922-8-3/03.count/D03658A1.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B922/out-B922-8-4/B922-8-4/03.count/D03658A1.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B922/out-B922-8-5/B922-8-5/03.count/D03658A1.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
]
idx = 1
cnt = []
for sample in samples:
    umi_list = []
    for i in range(idx):
        umi_list += pd.read_csv(samples[i], header=None)[0].tolist()
    umi_set = set(umi_list)
    cnt += [len(umi_set)]
    idx += 1
plt.plot([str(i) for i in range(5)], cnt)
plt.title("UMI count")
plt.show()

# %%
samples = [
    "/home/wpy/stereoseq/in_vivo_T_68/B924/out-B924-8-1/03.count/D03658A3.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B924/out-B924-8-2/B924-direct-8/03.count/D03658A3.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B924/out-B924-8-3/B924-direct-8/03.count/D03658A3.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B924/out-B924-8-4/B924-direct-8/03.count/D03658A3.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B924/out-B924-8-5/B924-direct-8/03.count/D03658A3.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt"
]
idx = 1
cnt = []
for sample in samples:
    umi_list = []
    for i in range(idx):
        umi_list += pd.read_csv(samples[i], header=None)[0].tolist()
    umi_set = set(umi_list)
    cnt += [len(umi_set)]
    idx += 1
plt.plot([str(i) for i in range(5)], cnt)
plt.title("UMI count")
plt.show()

# %%
samples = [
    "/home/wpy/stereoseq/in_vivo_T_68/B926/out-B926-8-1/03.count/D03658A6.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B926/out-B926-8-2/B926-direct-8/03.count/D03658A6.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B926/out-B926-8-3/B926-direct-8/03.count/D03658A6.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B926/out-B926-8-4/B926-direct-8/03.count/D03658A6.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B926/out-B926-8-5/B926-direct-8/03.count/D03658A6.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt"
]
idx = 1
cnt = []
for sample in samples:
    umi_list = []
    for i in range(idx):
        umi_list += pd.read_csv(samples[i], header=None)[0].tolist()
    umi_set = set(umi_list)
    cnt += [len(umi_set)]
    idx += 1
plt.plot([str(i) for i in range(5)], cnt)
plt.title("UMI count")
plt.show()

# %%
samples = [
    "/home/wpy/stereoseq/in_vivo_T_68/B922-2/out/B922-2-1/03.count/C03628E2.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B922-2/out/B922-2-2/03.count/C03628E2.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B922-2/out/B922-2-3/03.count/C03628E2.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B922-2/out/B922-2-4/03.count/C03628E2.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B922-2/out/B922-2-5/03.count/C03628E2.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt"
]
idx = 1
cnt = []
for sample in samples:
    umi_list = []
    for i in range(idx):
        umi_list += pd.read_csv(samples[i], header=None)[0].tolist()
    umi_set = set(umi_list)
    cnt += [len(umi_set)]
    idx += 1
plt.plot([str(i) for i in range(5)], cnt)
plt.title("UMI count")
plt.show()

# %%
samples = [
    "/home/wpy/stereoseq/in_vivo_T_68/B924-2/out/B924-2-1/03.count/C03628A1.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B924-2/out/B924-2-2/03.count/C03628A1.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B924-2/out/B924-2-3/03.count/C03628A1.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B924-2/out/B924-2-4/03.count/C03628A1.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B924-2/out/B924-2-5/03.count/C03628A1.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt"
]
idx = 1
cnt = []
for sample in samples:
    umi_list = []
    for i in range(idx):
        umi_list += pd.read_csv(samples[i], header=None)[0].tolist()
    umi_set = set(umi_list)
    cnt += [len(umi_set)]
    idx += 1
plt.plot([str(i) for i in range(5)], cnt)
plt.title("UMI count")
plt.show()

# %%
samples = [
    "/home/wpy/stereoseq/in_vivo_T_68/B926-2/out/B926-2-1/03.count/D03658A5.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B926-2/out/B926-2-2/03.count/D03658A5.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B926-2/out/B926-2-3/03.count/D03658A5.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B926-2/out/B926-2-4/03.count/D03658A5.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt",
    "/home/wpy/stereoseq/in_vivo_T_68/B926-2/out/B926-2-5/03.count/D03658A5.Aligned.sortedByCoord.out.merge.q10.dedup.target.bam.umi.txt"
]
idx = 1
cnt = []
for sample in samples:
    umi_list = []
    for i in range(idx):
        umi_list += pd.read_csv(samples[i], header=None)[0].tolist()
    umi_set = set(umi_list)
    cnt += [len(umi_set)]
    idx += 1
plt.plot([str(i) for i in range(5)], cnt)
plt.title("UMI count")
plt.show()
