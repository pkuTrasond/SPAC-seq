# %%
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt
import pandas as dp

# %%
adata = sc.read_h5ad('/data200T/zp_data/2102_dataset/No_1227_1_output.h5ad')

# %%
adata.obs.columns
# Out:
# Index(['3DUMAP1', '3DUMAP2', '3DUMAP3', '3DtSNE1', '3DtSNE2', '3DtSNE3',
#        'FACSMarker', 'cellID', 'cellOntologyID', 'cellOntologyName',
#        'clusterID', 'clusterName', 'clusterName_scibet',
#        'meta_CellOClassification', 'meta_patient', 'meta_phase',
#        'meta_sampleType', 'meta_scibetHCL', 'meta_scibetHPA',
#        'meta_scibetMajorType', 'meta_scibetSubType', 'meta_scibetTabulaMuris',
#        'meta_scibetTabulaSapiens', 'meta_sex(computationallyDerived)',
#        'meta_sourceName', 'meta_tissue', 'sampleID', 'stats_g2mScore',
#        'stats_mitoPercent', 'stats_numberOfGenes', 'stats_numberOfTotalCounts',
#        'stats_sScore'],
#       dtype='object')

# %%
sc.pl.umap(adata, color=['clusterName'])
# Out:
# /home/wpy/miniconda3/envs/scanpy/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/wpy/miniconda3/envs/scanpy/lib/python3.12/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
